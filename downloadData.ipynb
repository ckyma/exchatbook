# %%
# For data manipulation
import pandas as pd
import numpy as np

# To fetch financial data
import yfinance as yf

# %%
# Import the SSE Composite list as of 2023-06-18
ssci_list = pd.read_excel("index_constituents.xlsx", sheet_name = "ssci")

# Import the SZSE Composite list as of 2023-06-18
szci_list = pd.read_excel("index_constituents.xlsx", sheet_name = "szci")

# Import the Russell 2000 list as of 2023-06-18
rut_list = pd.read_excel("index_constituents.xlsx", sheet_name = "russell2000")

# Import the FTSE All Share list as of 2023-06-18
ftas_list = pd.read_excel("index_constituents.xlsx", sheet_name = "ftse")

# %%
# Import the FTSE All Share list as of 2023-07-09
cdax_list = pd.read_excel("index_constituents.xlsx", sheet_name = "cdax")

# Import the FTSE All Share list as of 2023-07-09
n400_list = pd.read_excel("index_constituents.xlsx", sheet_name = "jpxn400")

# %%
# Download SSCI data from 2000-01-01
ssci_data = yf.download(ssci_list["yahoo_code"].tolist(), start="2000-01-01", end="2023-06-18")

# Set the index to a datetime type
ssci_data.index = pd.to_datetime(ssci_data.index)

# Display the first five rows
print(ssci_data.head())

ssci_data.to_pickle("ssci_data.pkl")


# Download SZCI data from 2000-01-01
szci_data = yf.download(szci_list["yahoo_code"].tolist(), start="2000-01-01", end="2023-06-18")

# Set the index to a datetime type
szci_data.index = pd.to_datetime(szci_data.index)

# Display the first five rows
print(szci_data.head())

szci_data.to_pickle("szci_data.pkl")


# Download RUT data from 2000-01-01
rut_data = yf.download(rut_list["yahoo_code"].tolist(), start="2000-01-01", end="2023-06-18")

# Set the index to a datetime type
rut_data.index = pd.to_datetime(rut_data.index)

# Display the first five rows
print(rut_data.head())

rut_data.to_pickle("rut_data.pkl")


# Download ftas data from 2000-01-01
ftas_data = yf.download(ftas_list["yahoo_code"].tolist(), start="2000-01-01", end="2023-06-18")

# Set the index to a datetime type
ftas_data.index = pd.to_datetime(ftas_data.index)

# Display the first five rows
print(ftas_data.head())

ftas_data.to_pickle("ftas_data.pkl")
# Out:
# [*********************100%***********************]  2062 of 2062 completed
#            Adj Close                                                    \
#            600000.SS 600004.SS 600006.SS 600007.SS 600008.SS 600009.SS
# Date
# 2000-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2000-01-04  1.718937       NaN  1.331853  4.491885       NaN  2.935281
# 2000-01-05  1.699442       NaN  1.321177  4.498202       NaN  2.947262
# 2000-01-06  1.747171       NaN  1.363881  4.725640       NaN  2.992189
# 2000-01-07  1.808346       NaN  1.398578  5.092065       NaN  3.094026
#
#                                                     ...     Volume            \
#            600010.SS 600011.SS 600012.SS 600015.SS  ...  900941.SS 900942.SS
# Date                                                ...
# 2000-01-03       NaN       NaN       NaN       NaN  ...        NaN       NaN
# 2000-01-04       NaN       NaN       NaN       NaN  ...  1100000.0  605250.0
# 2000-01-05       NaN       NaN       NaN       NaN  ...   950000.0  267750.0
# 2000-01-06       NaN       NaN       NaN       NaN  ...   217000.0  121275.0
# 2000-01-07       NaN       NaN       NaN       NaN  ...   762000.0  807525.0
#
#                                                                           \
#            900943.SS 900945.SS 900946.SS 900947.SS  900948.SS  900952.SS
# Date
# 2000-01-03       NaN       NaN       NaN         0        NaN        NaN
# 2000-01-04   91000.0   28080.0   37400.0   1077336   752000.0    55800.0
# 2000-01-05   50000.0   74520.0  243000.0   3154320  1968000.0   169200.0
# 2000-01-06    7000.0  237600.0  141000.0   1094184   592000.0   163800.0
# 2000-01-07  261000.0  434160.0  301500.0   4520880  9458640.0  1362600.0
#
#
#            900953.SS 900957.SS
# Date
# 2000-01-03       NaN       NaN
# 2000-01-04   30000.0       NaN
# 2000-01-05   14000.0       NaN
# 2000-01-06   40000.0       NaN
# 2000-01-07  220500.0       NaN
#
# [5 rows x 12372 columns]
# [*********************100%***********************]  500 of 500 completed
#            Adj Close                                                    \
#            000001.SZ 000002.SZ 000009.SZ 000012.SZ 000021.SZ 000027.SZ
# Date
# 2000-01-03       NaN       NaN  1.131822  0.725237       NaN  1.467329
# 2000-01-04  4.271748  0.533575  1.147808  0.734639  9.012008  1.499310
# 2000-01-05  4.218031  0.520106  1.151006  0.742697  8.779312  1.503073
# 2000-01-06  4.386192  0.544454  1.192569  0.772244  9.301215  1.548221
# 2000-01-07  4.563695  0.569320  1.218147  0.797761  9.620341  1.619706
#
#                                                      ...    Volume            \
#            000028.SZ 000032.SZ  000035.SZ 000039.SZ  ... 301155.SZ 301177.SZ
# Date                                                 ...
# 2000-01-03  3.789914       NaN        NaN  0.935961  ...       NaN       NaN
# 2000-01-04  4.168905  8.236194   9.249137  0.972298  ...       NaN       NaN
# 2000-01-05  4.240413  8.022551   9.105104  0.959635  ...       NaN       NaN
# 2000-01-06  4.562198  8.257995   9.646196  1.016343  ...       NaN       NaN
# 2000-01-07  4.569349  8.462917  10.121108  1.046074  ...       NaN       NaN
#
#                                                                         \
#            301200.SZ 301207.SZ 301219.SZ 301236.SZ 301238.SZ 301268.SZ
# Date
# 2000-01-03       NaN       NaN       NaN       NaN       NaN       NaN
# 2000-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2000-01-05       NaN       NaN       NaN       NaN       NaN       NaN
# 2000-01-06       NaN       NaN       NaN       NaN       NaN       NaN
# 2000-01-07       NaN       NaN       NaN       NaN       NaN       NaN
#
#
#            301269.SZ 301308.SZ
# Date
# 2000-01-03       NaN       NaN
# 2000-01-04       NaN       NaN
# 2000-01-05       NaN       NaN
# 2000-01-06       NaN       NaN
# 2000-01-07       NaN       NaN
#
# [5 rows x 3000 columns]
# [******                12%                       ]  230 of 1895 completed
# ERROR Failed to get ticker 'LGF/A' reason: Expecting value: line 1 column 1 (char 0)
# [******                12%                       ]  232 of 1895 completed
# ERROR Failed to get ticker 'LGF/B' reason: Expecting value: line 1 column 1 (char 0)
# [**************        29%                       ]  552 of 1895 completed
# ERROR Failed to get ticker 'GEF/B' reason: Expecting value: line 1 column 1 (char 0)
# [**********************82%**************         ]  1563 of 1895 completed
# ERROR Failed to get ticker 'MOG/A' reason: Expecting value: line 1 column 1 (char 0)
# [**********************98%********************** ]  1852 of 1895 completed
# ERROR Failed to get ticker 'JW/A' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%***********************]  1895 of 1895 completed
# ERROR
# 220 Failed downloads:
# ERROR ['HBNC      ']: Exception('HBNC      : No timezone found, symbol may be delisted')
# ERROR ['FII']: Exception('FII: No timezone found, symbol may be delisted')
# ERROR ['WRE']: Exception('WRE: No timezone found, symbol may be delisted')
# ERROR ['OSTK      ']: Exception('OSTK      : No timezone found, symbol may be delisted')
# ERROR ['LBAI      ']: Exception('LBAI      : No timezone found, symbol may be delisted')
# ERROR ['SATS      ']: Exception('SATS      : No timezone found, symbol may be delisted')
# ERROR ['FOLD      ']: Exception('FOLD      : No timezone found, symbol may be delisted')
# ERROR ['GSAT      ']: Exception('GSAT      : No timezone found, symbol may be delisted')
# ERROR ['URG       ']: Exception('URG       : No timezone found, symbol may be delisted')
# ERROR ['CRAI      ']: Exception('CRAI      : No timezone found, symbol may be delisted')
# ERROR ['VEC']: Exception('VEC: No timezone found, symbol may be delisted')
# ERROR ['IMGN      ']: Exception('IMGN      : No timezone found, symbol may be delisted')
# ERROR ['IDT       ']: Exception('IDT       : No timezone found, symbol may be delisted')
# ERROR ['PACB      ']: Exception('PACB      : No timezone found, symbol may be delisted')
# ERROR ['KRO       ']: Exception('KRO       : No timezone found, symbol may be delisted')
# ERROR ['CCF       ']: Exception('CCF       : No timezone found, symbol may be delisted')
# ERROR ['DHIL      ']: Exception('DHIL      : No timezone found, symbol may be delisted')
# ERROR ['CRY']: Exception('CRY: No timezone found, symbol may be delisted')
# ERROR ['TRC       ']: Exception('TRC       : No timezone found, symbol may be delisted')
# ERROR ['GLRE      ']: Exception('GLRE      : No timezone found, symbol may be delisted')
# ERROR ['KAI       ']: Exception('KAI       : No timezone found, symbol may be delisted')
# ERROR ['BLX       ']: Exception('BLX       : No timezone found, symbol may be delisted')
# ERROR ['NHC       ']: Exception('NHC       : No timezone found, symbol may be delisted')
# ERROR ['ALTM']: Exception('ALTM: No timezone found, symbol may be delisted')
# ERROR ['RLGT      ']: Exception('RLGT      : No timezone found, symbol may be delisted')
# ERROR ['ATSG      ']: Exception('ATSG      : No timezone found, symbol may be delisted')
# ERROR ['HURN      ']: Exception('HURN      : No timezone found, symbol may be delisted')
# ERROR ['LGF/A']: Exception('LGF/A: No timezone found, symbol may be delisted')
# ERROR ['LGF/B']: Exception('LGF/B: No timezone found, symbol may be delisted')
# ERROR ['LKFN      ']: Exception('LKFN      : No timezone found, symbol may be delisted')
# ERROR ['WMK       ']: Exception('WMK       : No timezone found, symbol may be delisted')
# ERROR ['TGH       ']: Exception('TGH       : No timezone found, symbol may be delisted')
# ERROR ['SRI       ']: Exception('SRI       : No timezone found, symbol may be delisted')
# ERROR ['CNS       ']: Exception('CNS       : No timezone found, symbol may be delisted')
# ERROR ['VRNT      ']: Exception('VRNT      : No timezone found, symbol may be delisted')
# ERROR ['USNA      ']: Exception('USNA      : No timezone found, symbol may be delisted')
# ERROR ['HTBK      ']: Exception('HTBK      : No timezone found, symbol may be delisted')
# ERROR ['CONN      ']: Exception('CONN      : No timezone found, symbol may be delisted')
# ERROR ['CODI      ']: Exception('CODI      : No timezone found, symbol may be delisted')
# ERROR ['UVSP      ']: Exception('UVSP      : No timezone found, symbol may be delisted')
# ERROR ['BHB       ']: Exception('BHB       : No timezone found, symbol may be delisted')
# ERROR ['OAS']: Exception('OAS: No timezone found, symbol may be delisted')
# ERROR ['FLWS      ']: Exception('FLWS      : No timezone found, symbol may be delisted')
# ERROR ['HALO      ']: Exception('HALO      : No timezone found, symbol may be delisted')
# ERROR ['AOSL      ']: Exception('AOSL      : No timezone found, symbol may be delisted')
# ERROR ['BHLB      ']: Exception('BHLB      : No timezone found, symbol may be delisted')
# ERROR ['ERII      ']: Exception('ERII      : No timezone found, symbol may be delisted')
# ERROR ['UTL       ']: Exception('UTL       : No timezone found, symbol may be delisted')
# ERROR ['USM       ']: Exception('USM       : No timezone found, symbol may be delisted')
# ERROR ['WEYS      ']: Exception('WEYS      : No timezone found, symbol may be delisted')
# ERROR ['PRO       ']: Exception('PRO       : No timezone found, symbol may be delisted')
# ERROR ['SHEN      ']: Exception('SHEN      : No timezone found, symbol may be delisted')
# ERROR ['FISI      ']: Exception('FISI      : No timezone found, symbol may be delisted')
# ERROR ['UIS       ']: Exception('UIS       : No timezone found, symbol may be delisted')
# ERROR ['TTS']: Exception('TTS: No timezone found, symbol may be delisted')
# ERROR ['SGMO      ']: Exception('SGMO      : No timezone found, symbol may be delisted')
# ERROR ['CASS      ']: Exception('CASS      : No timezone found, symbol may be delisted')
# ERROR ['INFN      ']: Exception('INFN      : No timezone found, symbol may be delisted')
# ERROR ['CERS      ']: Exception('CERS      : No timezone found, symbol may be delisted')
# ERROR ['WASH      ']: Exception('WASH      : No timezone found, symbol may be delisted')
# ERROR ['DJCO      ']: Exception('DJCO      : No timezone found, symbol may be delisted')
# ERROR ['CCBG      ']: Exception('CCBG      : No timezone found, symbol may be delisted')
# ERROR ['BKD       ']: Exception('BKD       : No timezone found, symbol may be delisted')
# ERROR ['MPX       ']: Exception('MPX       : No timezone found, symbol may be delisted')
# ERROR ['GEF/B']: Exception('GEF/B: No timezone found, symbol may be delisted')
# ERROR ['GOOD      ']: Exception('GOOD      : No timezone found, symbol may be delisted')
# ERROR ['WSFS      ']: Exception('WSFS      : No timezone found, symbol may be delisted')
# ERROR ['CPK       ']: Exception('CPK       : No timezone found, symbol may be delisted')
# ERROR ['KFRC      ']: Exception('KFRC      : No timezone found, symbol may be delisted')
# ERROR ['ETH']: Exception('ETH: No timezone found, symbol may be delisted')
# ERROR ['AGX       ']: Exception('AGX       : No timezone found, symbol may be delisted')
# ERROR ['ATRO      ']: Exception('ATRO      : No timezone found, symbol may be delisted')
# ERROR ['THFF      ']: Exception('THFF      : No timezone found, symbol may be delisted')
# ERROR ['IRWD      ']: Exception('IRWD      : No timezone found, symbol may be delisted')
# ERROR ['MBI       ']: Exception('MBI       : No timezone found, symbol may be delisted')
# ERROR ['OLP       ']: Exception('OLP       : No timezone found, symbol may be delisted')
# ERROR ['GSBC      ']: Exception('GSBC      : No timezone found, symbol may be delisted')
# ERROR ['FBIZ      ']: Exception('FBIZ      : No timezone found, symbol may be delisted')
# ERROR ['DGICA     ']: Exception('DGICA     : No timezone found, symbol may be delisted')
# ERROR ['WINA      ']: Exception('WINA      : No timezone found, symbol may be delisted')
# ERROR ['HEES      ']: Exception('HEES      : No timezone found, symbol may be delisted')
# ERROR ['BLI']: Exception('BLI: No timezone found, symbol may be delisted')
# ERROR ['HCKT      ']: Exception('HCKT      : No timezone found, symbol may be delisted')
# ERROR ['FBNC      ']: Exception('FBNC      : No timezone found, symbol may be delisted')
# ERROR ['GTN       ']: Exception('GTN       : No timezone found, symbol may be delisted')
# ERROR ['SIGA      ']: Exception('SIGA      : No timezone found, symbol may be delisted')
# ERROR ['IMKTA     ']: Exception('IMKTA     : No timezone found, symbol may be delisted')
# ERROR ['CVI       ']: Exception('CVI       : No timezone found, symbol may be delisted')
# ERROR ['TRS       ']: Exception('TRS       : No timezone found, symbol may be delisted')
# ERROR ['GLDD      ']: Exception('GLDD      : No timezone found, symbol may be delisted')
# ERROR ['RUSHA     ']: Exception('RUSHA     : No timezone found, symbol may be delisted')
# ERROR ['EGBN      ']: Exception('EGBN      : No timezone found, symbol may be delisted')
# ERROR ['ACNB      ']: Exception('ACNB      : No timezone found, symbol may be delisted')
# ERROR ['QUAD      ']: Exception('QUAD      : No timezone found, symbol may be delisted')
# ERROR ['ADGI']: Exception('ADGI: No timezone found, symbol may be delisted')
# ERROR ['RLGY']: Exception('RLGY: No timezone found, symbol may be delisted')
# ERROR ['VNDA      ']: Exception('VNDA      : No timezone found, symbol may be delisted')
# ERROR ['TPC       ']: Exception('TPC       : No timezone found, symbol may be delisted')
# ERROR ['ORA       ']: Exception('ORA       : No timezone found, symbol may be delisted')
# ERROR ['BOMN']: Exception('BOMN: No timezone found, symbol may be delisted')
# ERROR ['OCFC      ']: Exception('OCFC      : No timezone found, symbol may be delisted')
# ERROR ['FIZZ      ']: Exception('FIZZ      : No timezone found, symbol may be delisted')
# ERROR ['CRD.A']: Exception('CRD.A: No timezone found, symbol may be delisted')
# ERROR ['WSBC      ']: Exception('WSBC      : No timezone found, symbol may be delisted')
# ERROR ['ELY']: Exception('ELY: No timezone found, symbol may be delisted')
# ERROR ['ADS']: Exception('ADS: No timezone found, symbol may be delisted')
# ERROR ['PFIS      ']: Exception('PFIS      : No timezone found, symbol may be delisted')
# ERROR ['WTI       ']: Exception('WTI       : No timezone found, symbol may be delisted')
# ERROR ['TCBK      ']: Exception('TCBK      : No timezone found, symbol may be delisted')
# ERROR ['OPK       ']: Exception('OPK       : No timezone found, symbol may be delisted')
# ERROR ['CVTI']: Exception('CVTI: No timezone found, symbol may be delisted')
# ERROR ['SRCE      ']: Exception('SRCE      : No timezone found, symbol may be delisted')
# ERROR ['FOR-W']: Exception('FOR-W: No timezone found, symbol may be delisted')
# ERROR ['BOFI']: Exception('BOFI: No price data found, symbol may be delisted (1d 2000-01-01 -> 2023-06-18)')
# ERROR ['MOD       ']: Exception('MOD       : No timezone found, symbol may be delisted')
# ERROR ['MLHR']: Exception('MLHR: No timezone found, symbol may be delisted')
# ERROR ['ORRF      ']: Exception('ORRF      : No timezone found, symbol may be delisted')
# ERROR ['ACAD      ']: Exception('ACAD      : No timezone found, symbol may be delisted')
# ERROR ['SGMS']: Exception('SGMS: No timezone found, symbol may be delisted')
# ERROR ['FDP       ']: Exception('FDP       : No timezone found, symbol may be delisted')
# ERROR ['LLNW      ']: Exception('LLNW      : No timezone found, symbol may be delisted')
# ERROR ['AGII']: Exception('AGII: No price data found, symbol may be delisted (1d 2000-01-01 -> 2023-06-18)')
# ERROR ['PFHC']: Exception('PFHC: No timezone found, symbol may be delisted')
# ERROR ['KW        ']: Exception('KW        : No timezone found, symbol may be delisted')
# ERROR ['MGEE      ']: Exception('MGEE      : No timezone found, symbol may be delisted')
# ERROR ['DCO       ']: Exception('DCO       : No timezone found, symbol may be delisted')
# ERROR ['CWEN.A']: Exception('CWEN.A: No timezone found, symbol may be delisted')
# ERROR ['DENN      ']: Exception('DENN      : No timezone found, symbol may be delisted')
# ERROR ['BCRX      ']: Exception('BCRX      : No timezone found, symbol may be delisted')
# ERROR ['FLIC      ']: Exception('FLIC      : No timezone found, symbol may be delisted')
# ERROR ['PSMT      ']: Exception('PSMT      : No timezone found, symbol may be delisted')
# ERROR ['MGRC      ']: Exception('MGRC      : No timezone found, symbol may be delisted')
# ERROR ['NNI       ']: Exception('NNI       : No timezone found, symbol may be delisted')
# ERROR ['NC        ']: Exception('NC        : No timezone found, symbol may be delisted')
# ERROR ['FFIC      ']: Exception('FFIC      : No timezone found, symbol may be delisted')
# ERROR ['AMRC      ']: Exception('AMRC      : No timezone found, symbol may be delisted')
# ERROR ['SB        ']: Exception('SB        : No timezone found, symbol may be delisted')
# ERROR ['ESGR      ']: Exception('ESGR      : No timezone found, symbol may be delisted')
# ERROR ['BCOR']: Exception('BCOR: No timezone found, symbol may be delisted')
# ERROR ['LNDC']: Exception('LNDC: No timezone found, symbol may be delisted')
# ERROR ['CLI']: Exception('CLI: No timezone found, symbol may be delisted')
# ERROR ['HL        ']: Exception('HL        : No timezone found, symbol may be delisted')
# ERROR ['FMBH      ']: Exception('FMBH      : No timezone found, symbol may be delisted')
# ERROR ['RBCAA     ']: Exception('RBCAA     : No timezone found, symbol may be delisted')
# ERROR ['HIFS      ']: Exception('HIFS      : No timezone found, symbol may be delisted')
# ERROR ['RWT       ']: Exception('RWT       : No timezone found, symbol may be delisted')
# ERROR ['FMNB      ']: Exception('FMNB      : No timezone found, symbol may be delisted')
# ERROR ['HBHC']: Exception('HBHC: No price data found, symbol may be delisted (1d 2000-01-01 -> 2023-06-18)')
# ERROR ['CALX      ']: Exception('CALX      : No timezone found, symbol may be delisted')
# ERROR ['FRBK      ']: Exception('FRBK      : No timezone found, symbol may be delisted')
# ERROR ['RCII']: Exception('RCII: No timezone found, symbol may be delisted')
# ERROR ['PGC       ']: Exception('PGC       : No timezone found, symbol may be delisted')
# ERROR ['CTBI      ']: Exception('CTBI      : No timezone found, symbol may be delisted')
# ERROR ['PRIM      ']: Exception('PRIM      : No timezone found, symbol may be delisted')
# ERROR ['AVID      ']: Exception('AVID      : No timezone found, symbol may be delisted')
# ERROR ['NWPX      ']: Exception('NWPX      : No timezone found, symbol may be delisted')
# ERROR ['KTOS      ']: Exception('KTOS      : No timezone found, symbol may be delisted')
# ERROR ['CSV       ']: Exception('CSV       : No timezone found, symbol may be delisted')
# ERROR ['CAC       ']: Exception('CAC       : No timezone found, symbol may be delisted')
# ERROR ['TITN      ']: Exception('TITN      : No timezone found, symbol may be delisted')
# ERROR ['VPG       ']: Exception('VPG       : No timezone found, symbol may be delisted')
# ERROR ['NL        ']: Exception('NL        : No timezone found, symbol may be delisted')
# ERROR ['MBWM      ']: Exception('MBWM      : No timezone found, symbol may be delisted')
# ERROR ['OFLX      ']: Exception('OFLX      : No timezone found, symbol may be delisted')
# ERROR ['TCI       ']: Exception('TCI       : No timezone found, symbol may be delisted')
# ERROR ['RIGL      ']: Exception('RIGL      : No timezone found, symbol may be delisted')
# ERROR ['CLNE      ']: Exception('CLNE      : No timezone found, symbol may be delisted')
# ERROR ['TTGT      ']: Exception('TTGT      : No timezone found, symbol may be delisted')
# ERROR ['CIX       ']: Exception('CIX       : No timezone found, symbol may be delisted')
# ERROR ['ATRI      ']: Exception('ATRI      : No timezone found, symbol may be delisted')
# ERROR ['LPI']: Exception('LPI: No timezone found, symbol may be delisted')
# ERROR ['JCOM']: Exception('JCOM: No timezone found, symbol may be delisted')
# ERROR ['IBCP      ']: Exception('IBCP      : No timezone found, symbol may be delisted')
# ERROR ['PRK       ']: Exception('PRK       : No timezone found, symbol may be delisted')
# ERROR ['GABC      ']: Exception('GABC      : No timezone found, symbol may be delisted')
# ERROR ['HFWA      ']: Exception('HFWA      : No timezone found, symbol may be delisted')
# ERROR ['RECN']: Exception('RECN: No timezone found, symbol may be delisted')
# ERROR ['VGR       ']: Exception('VGR       : No timezone found, symbol may be delisted')
# ERROR ['AGM       ']: Exception('AGM       : No timezone found, symbol may be delisted')
# ERROR ['TBK']: Exception('TBK: No timezone found, symbol may be delisted')
# ERROR ['LAWS']: Exception('LAWS: No timezone found, symbol may be delisted')
# ERROR ['FCBC      ']: Exception('FCBC      : No timezone found, symbol may be delisted')
# ERROR ['SCHN      ']: Exception('SCHN      : No timezone found, symbol may be delisted')
# ERROR ['JOE       ']: Exception('JOE       : No timezone found, symbol may be delisted')
# ERROR ['SWM']: Exception('SWM: No timezone found, symbol may be delisted')
# ERROR ['MOG/A']: Exception('MOG/A: No timezone found, symbol may be delisted')
# ERROR ['BBSI      ']: Exception('BBSI      : No timezone found, symbol may be delisted')
# ERROR ['MLAB      ']: Exception('MLAB      : No timezone found, symbol may be delisted')
# ERROR ['PJC']: Exception('PJC: No timezone found, symbol may be delisted')
# ERROR ['PLOW      ']: Exception('PLOW      : No timezone found, symbol may be delisted')
# ERROR ['EBF       ']: Exception('EBF       : No timezone found, symbol may be delisted')
# ERROR ['GERN      ']: Exception('GERN      : No timezone found, symbol may be delisted')
# ERROR ['ROLL      ']: Exception('ROLL      : No timezone found, symbol may be delisted')
# ERROR ['CTRN      ']: Exception('CTRN      : No timezone found, symbol may be delisted')
# ERROR ['NCBS']: Exception('NCBS: No timezone found, symbol may be delisted')
# ERROR ['EFSC      ']: Exception('EFSC      : No timezone found, symbol may be delisted')
# ERROR ['AFIN']: Exception('AFIN: No timezone found, symbol may be delisted')
# ERROR ['ICFI      ']: Exception('ICFI      : No timezone found, symbol may be delisted')
# ERROR ['CDE       ']: Exception('CDE       : No timezone found, symbol may be delisted')
# ERROR ['AROW      ']: Exception('AROW      : No timezone found, symbol may be delisted')
# ERROR ['GCBC      ']: Exception('GCBC      : No timezone found, symbol may be delisted')
# ERROR ['CBZ       ']: Exception('CBZ       : No timezone found, symbol may be delisted')
# ERROR ['NRCIA']: Exception('NRCIA: No price data found, symbol may be delisted (1d 2000-01-01 -> 2023-06-18)')
# ERROR ['CMCO      ']: Exception('CMCO      : No timezone found, symbol may be delisted')
# ERROR ['VLGEA     ']: Exception('VLGEA     : No timezone found, symbol may be delisted')
# ERROR ['STAA      ']: Exception('STAA      : No timezone found, symbol may be delisted')
# ERROR ['STRS      ']: Exception('STRS      : No timezone found, symbol may be delisted')
# ERROR ['HTH       ']: Exception('HTH       : No timezone found, symbol may be delisted')
# ERROR ['RUSHB     ']: Exception('RUSHB     : No timezone found, symbol may be delisted')
# ERROR ['ATRC      ']: Exception('ATRC      : No timezone found, symbol may be delisted')
# ERROR ['PEBO      ']: Exception('PEBO      : No timezone found, symbol may be delisted')
# ERROR ['OTTR      ']: Exception('OTTR      : No timezone found, symbol may be delisted')
# ERROR ['FRME      ']: Exception('FRME      : No timezone found, symbol may be delisted')
# ERROR ['AMKR      ']: Exception('AMKR      : No timezone found, symbol may be delisted')
# ERROR ['RNST      ']: Exception('RNST      : No timezone found, symbol may be delisted')
# ERROR ['WETF']: Exception('WETF: No timezone found, symbol may be delisted')
# ERROR ['QCRH      ']: Exception('QCRH      : No timezone found, symbol may be delisted')
# ERROR ['PVAC']: Exception('PVAC: No timezone found, symbol may be delisted')
# ERROR ['JW/A']: Exception('JW/A: No timezone found, symbol may be delisted')
# ERROR ['BANF      ']: Exception('BANF      : No timezone found, symbol may be delisted')
#            Adj Close                                                          \
#                 AADI AAN      AAON AAT      ABCB ABCL ABG       ABM ABR ABSI
# Date
# 2000-01-03       NaN NaN  0.997502 NaN  5.879150  NaN NaN  6.130104 NaN  NaN
# 2000-01-04       NaN NaN  1.039065 NaN  5.810787  NaN NaN  6.148964 NaN  NaN
# 2000-01-05       NaN NaN  1.048301 NaN  5.810787  NaN NaN  6.073520 NaN  NaN
# 2000-01-06       NaN NaN  1.052919 NaN  5.810787  NaN NaN  6.092384 NaN  NaN
# 2000-01-07       NaN NaN  1.015974 NaN  5.879150  NaN NaN  6.111243 NaN  NaN
#
#             ... Volume
#             ...   ZEUS ZEV ZGN ZIMV ZIP ZNTL ZUMZ ZUO ZWS ZYXI
# Date        ...
# 2000-01-03  ...  15300 NaN NaN  NaN NaN  NaN  NaN NaN NaN  NaN
# 2000-01-04  ...  10100 NaN NaN  NaN NaN  NaN  NaN NaN NaN  NaN
# 2000-01-05  ...  30500 NaN NaN  NaN NaN  NaN  NaN NaN NaN  NaN
# 2000-01-06  ...  27000 NaN NaN  NaN NaN  NaN  NaN NaN NaN  NaN
# 2000-01-07  ...  57200 NaN NaN  NaN NaN  NaN  NaN NaN NaN  NaN
#
# [5 rows x 11370 columns]
# [*********************100%***********************]  576 of 576 completed
# ERROR
# 3 Failed downloads:
# ERROR ['HFEL.L']: Exception('HFEL.L: No timezone found, symbol may be delisted')
# ERROR ['SJG.L']: Exception('SJG.L: No timezone found, symbol may be delisted')
# ERROR ['ATST.L']: Exception('ATST.L: No timezone found, symbol may be delisted')
#            Adj Close                                                       \
#                3IN.L 888.L AAF.L AAIF.L       AAL.L      AAS.L      ABD.L
# Date
# 2000-01-03       NaN   NaN   NaN    NaN  528.104309  16.367298  35.416176
# 2000-01-04       NaN   NaN   NaN    NaN  513.345642  16.450377  35.504055
# 2000-01-05       NaN   NaN   NaN    NaN  517.837463  15.702636  33.922188
# 2000-01-06       NaN   NaN   NaN    NaN  530.542664  15.328760  33.043388
# 2000-01-07       NaN   NaN   NaN    NaN  549.279846  15.411841  33.746429
#
#                                       ... Volume                       \
#            ABDN.L       ABF.L ACIC.L  ... WOSG.L WPP.L WPS.L   WTAN.L
# Date                                  ...
# 2000-01-03    NaN  220.049591  130.5  ...    NaN   0.0   NaN        0
# 2000-01-04    NaN  213.143005  129.5  ...    NaN   0.0   NaN   569560
# 2000-01-05    NaN  216.516037  124.5  ...    NaN   0.0   NaN   561760
# 2000-01-06    NaN  237.075470  123.5  ...    NaN   0.0   NaN  3517575
# 2000-01-07    NaN  230.008087  126.0  ...    NaN   0.0   NaN  5399380
#
#
#                 WTB.L    WWH.L     XAR.L XPP.L XPS.L    ZTF.L
# Date
# 2000-01-03        0.0        0       0.0   NaN   NaN      0.0
# 2000-01-04   998988.0    69734  365478.0   NaN   NaN  10000.0
# 2000-01-05  1885439.0    52647  480046.0   NaN   NaN   1505.0
# 2000-01-06  2574347.0  1002180  132722.0   NaN   NaN   5800.0
# 2000-01-07  3027659.0    61192  678903.0   NaN   NaN   2000.0
#
# [5 rows x 3456 columns]

# %%
# Download RUT data from 2000-01-01
rut_data = yf.download(rut_list["yahoo_code"].tolist(), start="2000-01-01", end="2023-06-18")

# Set the index to a datetime type
rut_data.index = pd.to_datetime(rut_data.index)

# Display the first five rows
print(rut_data.head())

rut_data.to_pickle("rut_data.pkl")
# Out:
# [*********************100%***********************]  1895 of 1895 completed
# ERROR
# 41 Failed downloads:
# ERROR ['ROLL']: Exception('ROLL: No timezone found, symbol may be delisted')
# ERROR ['LLNW']: Exception('LLNW: No timezone found, symbol may be delisted')
# ERROR ['VEC']: Exception('VEC: No timezone found, symbol may be delisted')
# ERROR ['CRY']: Exception('CRY: No timezone found, symbol may be delisted')
# ERROR ['ALTM']: Exception('ALTM: No timezone found, symbol may be delisted')
# ERROR ['OAS']: Exception('OAS: No timezone found, symbol may be delisted')
# ERROR ['TTS']: Exception('TTS: No timezone found, symbol may be delisted')
# ERROR ['ETH']: Exception('ETH: No timezone found, symbol may be delisted')
# ERROR ['BLI']: Exception('BLI: No timezone found, symbol may be delisted')
# ERROR ['FII']: Exception('FII: No timezone found, symbol may be delisted')
# ERROR ['ADGI']: Exception('ADGI: No timezone found, symbol may be delisted')
# ERROR ['RLGY']: Exception('RLGY: No timezone found, symbol may be delisted')
# ERROR ['BOMN']: Exception('BOMN: No timezone found, symbol may be delisted')
# ERROR ['ELY']: Exception('ELY: No timezone found, symbol may be delisted')
# ERROR ['ADS']: Exception('ADS: No timezone found, symbol may be delisted')
# ERROR ['CVTI']: Exception('CVTI: No timezone found, symbol may be delisted')
# ERROR ['FOR-W']: Exception('FOR-W: No timezone found, symbol may be delisted')
# ERROR ['BOFI']: Exception('BOFI: No price data found, symbol may be delisted (1d 2000-01-01 -> 2023-06-18)')
# ERROR ['MLHR']: Exception('MLHR: No timezone found, symbol may be delisted')
# ERROR ['SGMS']: Exception('SGMS: No timezone found, symbol may be delisted')
# ERROR ['AGII']: Exception('AGII: No price data found, symbol may be delisted (1d 2000-01-01 -> 2023-06-18)')
# ERROR ['PFHC']: Exception('PFHC: No timezone found, symbol may be delisted')
# ERROR ['BCOR']: Exception('BCOR: No timezone found, symbol may be delisted')
# ERROR ['LNDC']: Exception('LNDC: No timezone found, symbol may be delisted')
# ERROR ['CLI']: Exception('CLI: No timezone found, symbol may be delisted')
# ERROR ['WRE']: Exception('WRE: No timezone found, symbol may be delisted')
# ERROR ['HBHC']: Exception('HBHC: No price data found, symbol may be delisted (1d 2000-01-01 -> 2023-06-18)')
# ERROR ['RCII']: Exception('RCII: No timezone found, symbol may be delisted')
# ERROR ['JW-A']: Exception('JW-A: No timezone found, symbol may be delisted')
# ERROR ['LPI']: Exception('LPI: No timezone found, symbol may be delisted')
# ERROR ['JCOM']: Exception('JCOM: No timezone found, symbol may be delisted')
# ERROR ['RECN']: Exception('RECN: No timezone found, symbol may be delisted')
# ERROR ['TBK']: Exception('TBK: No timezone found, symbol may be delisted')
# ERROR ['LAWS']: Exception('LAWS: No timezone found, symbol may be delisted')
# ERROR ['SWM']: Exception('SWM: No timezone found, symbol may be delisted')
# ERROR ['PJC']: Exception('PJC: No timezone found, symbol may be delisted')
# ERROR ['AFIN']: Exception('AFIN: No timezone found, symbol may be delisted')
# ERROR ['NCBS']: Exception('NCBS: No timezone found, symbol may be delisted')
# ERROR ['NRCIA']: Exception('NRCIA: No price data found, symbol may be delisted (1d 2000-01-01 -> 2023-06-18)')
# ERROR ['WETF']: Exception('WETF: No timezone found, symbol may be delisted')
# ERROR ['PVAC']: Exception('PVAC: No timezone found, symbol may be delisted')
#            Adj Close                                                          \
#                 AADI AAN      AAON AAT      ABCB ABCL ABG       ABM ABR ABSI
# Date
# 2000-01-03       NaN NaN  0.997502 NaN  5.879150  NaN NaN  5.987932 NaN  NaN
# 2000-01-04       NaN NaN  1.039065 NaN  5.810787  NaN NaN  6.006357 NaN  NaN
# 2000-01-05       NaN NaN  1.048301 NaN  5.810787  NaN NaN  5.932659 NaN  NaN
# 2000-01-06       NaN NaN  1.052919 NaN  5.810787  NaN NaN  5.951084 NaN  NaN
# 2000-01-07       NaN NaN  1.015974 NaN  5.879150  NaN NaN  5.969507 NaN  NaN
#
#             ... Volume
#             ...   ZEUS ZEV ZGN ZIMV ZIP ZNTL ZUMZ ZUO ZWS ZYXI
# Date        ...
# 2000-01-03  ...  15300 NaN NaN  NaN NaN  NaN  NaN NaN NaN  NaN
# 2000-01-04  ...  10100 NaN NaN  NaN NaN  NaN  NaN NaN NaN  NaN
# 2000-01-05  ...  30500 NaN NaN  NaN NaN  NaN  NaN NaN NaN  NaN
# 2000-01-06  ...  27000 NaN NaN  NaN NaN  NaN  NaN NaN NaN  NaN
# 2000-01-07  ...  57200 NaN NaN  NaN NaN  NaN  NaN NaN NaN  NaN
#
# [5 rows x 11370 columns]

# %%
# Download cdax data from 2000-01-01
cdax_data = yf.download(cdax_list["yahoo_code"].tolist(), start="2000-01-01", end="2023-06-30")

# Set the index to a datetime type
cdax_data.index = pd.to_datetime(cdax_data.index)

# Display the first five rows
print(cdax_data.head())

cdax_data.to_pickle("cdax_data.pkl")
# Out:
# [*********************100%***********************]  380 of 380 completed
# ERROR
# 1 Failed download:
# ERROR ['WOLF.DE']: Exception("WOLF.DE: Period 'max' is invalid, must be one of ['1d', '5d']")
#            Adj Close                                                           \
#                02P.F 1COV.DE    1U1.DE 2HRA.DE 2INV.DE 3330.F 8TRA.DE A1OS.DE
# Date
# 2000-01-03       NaN     NaN  3.856218     NaN     NaN    NaN     NaN     NaN
# 2000-01-04       NaN     NaN  3.910916     NaN     NaN    NaN     NaN     NaN
# 2000-01-05       NaN     NaN  3.856218     NaN     NaN    NaN     NaN     NaN
# 2000-01-06       NaN     NaN  3.774170     NaN     NaN    NaN     NaN     NaN
# 2000-01-07       NaN     NaN  3.774170     NaN     NaN    NaN     NaN     NaN
#
#                              ... Volume                                     \
#            A4Y.DE    AAD.DE  ... WUG3.F WUW.DE WWG.F   YMO.F YOC.DE YOU.DE
# Date                         ...
# 2000-01-03    NaN  3.705400  ...    NaN  951.0  24.0  7500.0    NaN    NaN
# 2000-01-04    NaN  3.993198  ...    NaN  775.0  52.0  2500.0    NaN    NaN
# 2000-01-05    NaN  3.885274  ...  500.0  135.0  20.0     0.0    NaN    NaN
# 2000-01-06    NaN  3.723387  ...   45.0    0.0  41.0   375.0    NaN    NaN
# 2000-01-07    NaN  3.950028  ...  400.0    0.0  28.0   100.0    NaN    NaN
#
#
#              YSN.DE ZAL.DE ZEF.F ZIL2.DE
# Date
# 2000-01-03   5018.0    NaN   NaN     NaN
# 2000-01-04  12044.0    NaN   NaN     NaN
# 2000-01-05   8083.0    NaN   NaN     NaN
# 2000-01-06   5666.0    NaN   NaN     NaN
# 2000-01-07   4092.0    NaN   NaN     NaN
#
# [5 rows x 2280 columns]

# %%
# Download cdax data from 2000-01-01
n400_data = yf.download(n400_list["yahoo_code"].tolist(), start="2000-01-01", end="2023-06-30")

# Set the index to a datetime type
n400_data.index = pd.to_datetime(n400_data.index)

# Display the first five rows
print(n400_data.head())

n400_data.to_pickle("n400_data.pkl")
# Out:
# [*********************100%***********************]  399 of 399 completed
#              Adj Close                                                 \
#                 1332.T 1407.T 1414.T 1417.T      1605.T 1719.T 1721.T
# Date
# 2000-01-03         NaN    NaN    NaN    NaN         NaN    NaN    NaN
# 2000-01-04  100.753326    NaN    NaN    NaN  362.720306    NaN    NaN
# 2000-01-05  100.753326    NaN    NaN    NaN  362.720306    NaN    NaN
# 2000-01-06  104.603775    NaN    NaN    NaN  357.883911    NaN    NaN
# 2000-01-07  108.454208    NaN    NaN    NaN  360.302002    NaN    NaN
#
#                                                 ... Volume                   \
#                 1801.T      1802.T      1803.T  ... 9744.T 9759.T    9766.T
# Date                                            ...
# 2000-01-03         NaN         NaN         NaN  ...    NaN    NaN       NaN
# 2000-01-04  567.256653  302.641541  238.521454  ...    NaN    NaN  297200.0
# 2000-01-05  612.040039  288.377686  243.490601  ...    NaN    NaN  520200.0
# 2000-01-06  570.242188  266.671814  231.422592  ...    NaN    NaN  397000.0
# 2000-01-07  579.198914  280.315338  243.490601  ...    NaN    NaN  602400.0
#
#
#            9787.T 9810.T 9843.T 9962.T     9983.T      9984.T 9989.T
# Date
# 2000-01-03    NaN    NaN    NaN    NaN        NaN         NaN    NaN
# 2000-01-04    NaN    NaN    NaN    NaN   981600.0   9909000.0    NaN
# 2000-01-05    NaN    NaN    NaN    NaN  3148800.0  84618000.0    NaN
# 2000-01-06    NaN    NaN    NaN    NaN  2200800.0  28085400.0    NaN
# 2000-01-07    NaN    NaN    NaN    NaN  2680800.0  58633200.0    NaN
#
# [5 rows x 2394 columns]
